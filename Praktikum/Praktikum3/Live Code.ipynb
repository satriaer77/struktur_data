# %%
from modules import stack as st

def printToken(num,stro,stOp) :
    print("""
-> Read Token - %d : %s
Stack = %s
    """ % (num,stro,stOp))

def convertPostfix(strOp) :
    stOperator = st.stack()
    kurung     = ("(",")")
    operator   = {"+":0,"-":0,"*":1,"/":1}
    strRes     = ""
    numStr     = 1
    
    for sto in strOp :
        if sto not in operator.keys() and sto not in kurung :
            strRes+=sto
        
        elif sto == kurung[0] :
            st.push(stOperator,sto)
            
        elif sto == kurung[1] :
            while st.peek(stOperator) != kurung[0] :
                strRes+=st.pop(stOperator)
            st.pop(stOperator)
            
            
        elif sto in operator.keys() :
            while not(st.isEmpty(stOperator)) and st.peek(stOperator) != kurung[0] and operator[st.peek(stOperator)] >= operator[sto] :   
                strRes+=st.pop(stOperator)
            st.push(stOperator,sto)
        printToken(numStr,sto,stOperator)
        numStr+=1
            
    while not(st.isEmpty(stOperator)) :
        strRes+=st.pop(stOperator)
            
            
    return strRes


print("Postfix : ",convertPostfix("(A*(B+C))-D"))
#print("Postfix : ",convertPostfix("(2*7)+1"))
print("Postfix : ",convertPostfix("a+b*c/d-f+g*h"))
# Out:
# -> Read Token - 1 : (
# Stack = ['(']
#
#
# -> Read Token - 2 : A
# Stack = ['(']
#
#
# -> Read Token - 3 : *
# Stack = ['(', '*']
#
#
# -> Read Token - 4 : (
# Stack = ['(', '*', '(']
#
#
# -> Read Token - 5 : B
# Stack = ['(', '*', '(']
#
#
# -> Read Token - 6 : +
# Stack = ['(', '*', '(', '+']
#
#
# -> Read Token - 7 : C
# Stack = ['(', '*', '(', '+']
#
#
# -> Read Token - 8 : )
# Stack = ['(', '*']
#
#
# -> Read Token - 9 : )
# Stack = []
#
#
# -> Read Token - 10 : -
# Stack = ['-']
#
#
# -> Read Token - 11 : D
# Stack = ['-']
#
# Postfix :  ABC+*D-
#
# -> Read Token - 1 : a
# Stack = []
#
#
# -> Read Token - 2 : +
# Stack = ['+']
#
#
# -> Read Token - 3 : b
# Stack = ['+']
#
#
# -> Read Token - 4 : *
# Stack = ['+', '*']
#
#
# -> Read Token - 5 : c
# Stack = ['+', '*']
#
#
# -> Read Token - 6 : /
# Stack = ['+', '/']
#
#
# -> Read Token - 7 : d
# Stack = ['+', '/']
#
#
# -> Read Token - 8 : -
# Stack = ['-']
#
#
# -> Read Token - 9 : f
# Stack = ['-']
#
#
# -> Read Token - 10 : +
# Stack = ['+']
#
#
# -> Read Token - 11 : g
# Stack = ['+']
#
#
# -> Read Token - 12 : *
# Stack = ['+', '*']
#
#
# -> Read Token - 13 : h
# Stack = ['+', '*']
#
# Postfix :  abc*d/+f-gh*+

# %%
from modules import stack as st

def printToken(num,stro,stOp) :
    print("""
-> Read Token - %d : %s
Stack = %s
    """ % (num,stro,stOp))

def convertPostfix(strOp) :
    stOperator = st.stack()
    kurung     = ("(",")")
    operator   = ("+","-","*","/")
    strRes     = ""
    numStr     = 1
    
    for sto in strOp :
        if sto not in operator and sto not in kurung :
            strRes+=sto
        
        elif sto == kurung[0] :
            st.push(stOperator,sto)
            
        elif sto == kurung[1] :
            while st.peek(stOperator) != kurung[0] :
                strRes+=st.pop(stOperator)
            st.pop(stOperator)
            
            
        elif sto in operator :
          
            while not(st.isEmpty(stOperator)) and st.peek(stOperator) != kurung[0] and operator.index(st.peek(stOperator)) > operator.index(sto)   :
                strRes+=st.pop(stOperator)
            st.push(stOperator,sto)
        printToken(numStr,sto,stOperator)
        numStr+=1
            
    while not(st.isEmpty(stOperator)) :
        strRes+=st.pop(stOperator)
            
            
    return strRes


print("Postfix : ",convertPostfix("(A*(B+C))-D"))
print("Postfix : ",convertPostfix("a+b*c/d-f+g*h"))
# Out:
# -> Read Token - 1 : (
# Stack = ['(']
#
#
# -> Read Token - 2 : A
# Stack = ['(']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_31550/4056613575.py in <module>
#      42
#      43
# ---> 44 print("Postfix : ",convertPostfix("(A*(B+C))-D"))
#      45 print("Postfix : ",convertPostfix("a+b*c/d-f+g*h"))
#
# /tmp/ipykernel_31550/4056613575.py in convertPostfix(strOp)
#      30
#      31             while not(st.isEmpty(stOperator)) and st.peek(stOperator) != kurung[0] and operator.index(st.peek(stOperator)) > operator.index(sto) or operator.index(sto) >= 2  :
# ---> 32                 strRes+=st.pop(stOperator)
#      33             st.push(stOperator,sto)
#      34         printToken(numStr,sto,stOperator)
#
# ~/Documents/Akademik/SEMESTER 2/STRUKDAT/Praktikum/Untitled Folder/modules/stack.py in pop(s)
#       8
#       9 def pop(s) :
# ---> 10     dt = s.pop()
#      11     return dt
#      12
#
# IndexError: pop from empty list

# %%
from modules import stack as st

def printToken(numStr,stro,stOp) :
    print("""
-> Read Token %d : %s
Stack : %s
    
    """ % (numStr,stro,stOp) )

def convertPostfix(strOp) :
    stOperator = st.stack()
    operator   = {"+":0,"-":0,"*":1,"/":1}
    kurung     = ("(",")")
    strRes     = ""
    num        = 1
    
    for sto in strOp :
        if sto not in operator.keys() and sto not in kurung :
            strRes+=sto
            
        elif sto == kurung[0]:
            st.push(stOperator,sto)
        
        elif sto == kurung[1] :
            while st.peek(stOperator) != kurung[0] and not(st.isEmpty(stOperator)) :
                strRes+=st.pop(stOperator)
            st.pop(stOperator)
            
        elif sto in operator.keys() :
            
            while not(st.isEmpty(stOperator)) and st.peek(stOperator) != kurung[0] and operator[st.peek(stOperator)] >= operator[sto] :    
                strRes+=st.pop(stOperator)
            st.push(stOperator,sto)
        
        printToken(num,sto,stOperator)
        num+=1
        
    while not(st.isEmpty(stOperator)) :
        strRes+=st.pop(stOperator)
    return strRes


print("Postfix : ",convertPostfix("(A*(B+C))-D"))
print("Postfix : ",convertPostfix("a+b*c/d-f+g*h"))
# Out:
# -> Read Token 1 : (
# Stack : ['(']
#
#
#
# -> Read Token 2 : A
# Stack : ['(']
#
#
#
# -> Read Token 3 : *
# Stack : ['(', '*']
#
#
#
# -> Read Token 4 : (
# Stack : ['(', '*', '(']
#
#
#
# -> Read Token 5 : B
# Stack : ['(', '*', '(']
#
#
#
# -> Read Token 6 : +
# Stack : ['(', '*', '(', '+']
#
#
#
# -> Read Token 7 : C
# Stack : ['(', '*', '(', '+']
#
#
#
# -> Read Token 8 : )
# Stack : ['(', '*']
#
#
#
# -> Read Token 9 : )
# Stack : []
#
#
#
# -> Read Token 10 : -
# Stack : ['-']
#
#
#
# -> Read Token 11 : D
# Stack : ['-']
#
#
# Postfix :  ABC+*D-
#
# -> Read Token 1 : a
# Stack : []
#
#
#
# -> Read Token 2 : +
# Stack : ['+']
#
#
#
# -> Read Token 3 : b
# Stack : ['+']
#
#
#
# -> Read Token 4 : *
# Stack : ['+', '*']
#
#
#
# -> Read Token 5 : c
# Stack : ['+', '*']
#
#
#
# -> Read Token 6 : /
# Stack : ['+', '/']
#
#
#
# -> Read Token 7 : d
# Stack : ['+', '/']
#
#
#
# -> Read Token 8 : -
# Stack : ['-']
#
#
#
# -> Read Token 9 : f
# Stack : ['-']
#
#
#
# -> Read Token 10 : +
# Stack : ['+']
#
#
#
# -> Read Token 11 : g
# Stack : ['+']
#
#
#
# -> Read Token 12 : *
# Stack : ['+', '*']
#
#
#
# -> Read Token 13 : h
# Stack : ['+', '*']
#
#
# Postfix :  abc*d/+f-gh*+
